# %%
# !wget https://zenodo.org/record/1154821/files/berlin.zip?download=1

# %%
import sys
sys.path.append('../')

# %%
import os, glob
import numpy as np
import matplotlib.pyplot as plt
import cv2
from utils.vis import *


# all_ = [x for x in glob.glob('/content/data/potsdam/*') if x.__contains__('image')]

# %%
def getImages(src, max_=5):
    images = [x for x in glob.glob(os.path.join(src, '*')) if x.__contains__('image')][:max_]
    masks = [img.replace('image.png', 'labels.png') for img in images]
    multiShowImageMask(images, masks, use_path=True, debug=True)

# %%
getImages('/content/data/berlin/')
